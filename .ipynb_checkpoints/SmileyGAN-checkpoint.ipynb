# %%
from keras.layers import Dense, BatchNormalization, Activation, UpSampling2D, Conv2D, Conv2DTranspose, Reshape, Dropout, Flatten, MaxPooling2D
from keras.models import Sequential, Model, Input
from keras import optimizers, losses, initializers
from keras.layers.advanced_activations import LeakyReLU
import numpy as np
import scipy.io as sio
import sys
import matplotlib.pyplot as plt
import cv2
import keras
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /Users/nickstepanov/miniconda3/envs/RoboND/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
class Generator():
    
    def __init__(self):
        g_input = Input(shape=[100])
        H = Dense(32*32*12)(g_input)
        H = BatchNormalization()(H)
        H = Reshape( [64,64, 3] )(H)
        H = Conv2D(128, kernel_size=(5,5), strides=2, padding='same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2DTranspose(128, kernel_size=(2,2), strides=4, padding='same')(H)
        H = LeakyReLU()(H)
        H = Conv2D(128, kernel_size=(5,5), strides=2, padding='same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2D(128, kernel_size=(5,5), strides=2, padding='same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2D(3, kernel_size=(5,5), strides=2, padding='same')(H)
        H = UpSampling2D((2,2))(H)
        H = BatchNormalization()(H)
        g_V = Activation('sigmoid')(H)
        self.model = Model(g_input,g_V)
        self.model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(lr=0.0007))
    def forward(self, inputs):
        return self.model.predict(inputs)   
generator = Generator()
generator.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12288)             1241088
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 12288)             49152
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       9728
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 128, 128, 128)     65664
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 128)       409728
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       409728
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 3)         9603
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 3)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 3)         12
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 2,196,239
# Trainable params: 2,170,889
# Non-trainable params: 25,350
# _________________________________________________________________

# %%
class Discriminator():
    def __init__(self):# Build Discriminative model ...
        d_input = Input(shape=[32,32,3])
        dropout_rate = 0.25
        #H = UpSampling2D((4,4))(d_input)
        H = Conv2D(128, (3, 3), strides=1, padding = 'same')(d_input)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2D(128, (4, 4), strides=(2, 2), padding = 'same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2D(128, (4, 4), strides=(2, 2), padding = 'same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Conv2D(128, (4, 4), strides=(2, 2), padding = 'same')(H)
        H = BatchNormalization()(H)
        H = LeakyReLU()(H)
        H = Reshape([128*16])(H)
        H = Dropout(dropout_rate)(H)
        d_V = Dense(1, activation='sigmoid')(H)
        self.model = Model(d_input,d_V)
        self.model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(lr=0.0001))
    def forward(self, inputs):
        return self.model.predict(inputs)
discriminator = Discriminator()
discriminator.model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       3584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       262272
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 128)         262272
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 128)         262272
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 794,497
# Trainable params: 793,473
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
#Plot generated Images
def plot_gen(n_ex=16,dim=(5,5), figsize=(10,10) ):
    noise = np.random.uniform(0,1,size=[5,100])
    generated_images = generator.forward(noise)

    plt.figure(figsize=figsize)
    #print(generated_images.shape)
    for i in range(generated_images.shape[0]):
        plt.subplot(dim[0],dim[1],i+1)
        img = np.zeros([32,32,3])
        #print(img.shape)
        img[:,:,0] = 255*generated_images[i,:,:,0]
        img[:,:,1] = 255*generated_images[i,:,:, 1]
        img[:,:,2] = 255*generated_images[i,:,:, 2]
        #print(img[:,:,0].shape)
        plt.imshow(img.astype(np.uint8))
        plt.axis('off')
    #plt.tight_layout()
    plt.show()

# %%
plot_gen()

# %%
# Build stacked GAN model
gan_input = Input(shape=[100])
generator.model(gan_input)
H = generator.model(gan_input)
gan_V = discriminator.model(H)
GAN = Model(inputs=gan_input, outputs=gan_V)
#GAN = Sequential()
#GAN.add(generator)
#GAN.add(discriminator)
GAN.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(), metics = ['binary_crossentropy'])
GAN.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# model_1 (Model)              (None, 32, 32, 3)         2196239
# _________________________________________________________________
# model_2 (Model)              (None, 1)                 794497
# =================================================================
# Total params: 2,990,736
# Trainable params: 2,964,362
# Non-trainable params: 26,374
# _________________________________________________________________

# %%
from os import listdir
import scipy.misc
def loadImages(path):
    # return array of images

    imagesList = listdir(path)
   
    loadedImages = []
    for image in imagesList:
        if image != '.DS_Store':
            img = cv2.imread(path + image)
            loadedImages.append(img.copy())       
    return loadedImages

path = "/Users/nickstepanov/GAN/EmojiOne/"

# your images in an array
def real_imgs():
    imgs = loadImages(path)
    X_train = []
    Y_train = []
    for img in imgs:
        # you can show every image
        #print(img)
        #pix = scipy.misc.imresize(np.array(img.getdata()).reshape(img.size[0], img.size[1], 3),(32,32))
        X_train.append(img)
        Y_train.append([0])
    X_train = np.array(X_train)
    X_train = X_train/255.
    Y_train = np.array(Y_train)
    return X_train, Y_train

# %%
#real_imgs()

# %%
#Train Discriminator on True dataset
def train_disc(X,Y,epochs=1):
    while epochs>0:
        print ("Epochs on discriminator left: %d "%(epochs))
        discriminator.model.fit(X,Y, batch_size=32,shuffle=True)
        epochs = epochs - 1
def disc_pred(X):
    return discriminator.forward(X)

# %%
#Generate Fake dataset
def gen_fake():
    X_fake = []
    Y_fake = []
    numP = 500
    img = generator.forward(np.random.uniform(0,1,size=[numP,100]))
    X_fake = np.array(img)
    X_fake = X_fake/255.

    for i in range(numP):
        Y_fake.append([1])
    return np.array(X_fake), np.array(Y_fake)

# %%
def accuracy(X,Y):
    y_hat = discriminator.forward(X)
    y_hat_idx = np.argmax(y_hat,axis=1)
    y_idx = np.argmax(Y,axis=0)
    diff = y_idx-y_hat_idx
    n_tot = X_train.shape[0]
    n_rig = (diff==0).sum()
    acc = n_rig*100.0/n_tot
    print ("Accuracy: %0.02f pct (%d of %d) right"%(acc, n_rig, n_tot))

# %%
# Freeze weights in the discriminator for stacked training
def make_trainable(net, val):
    net.trainable = val
    for l in net.model.layers:
        l.trainable = val
        #print(l.trainable, l)
    net.model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(lr=0.0001))
    GAN.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(lr=0.0001))
    #GAN.summary()

# %%
 # train Generator-Discriminator stack on input noise to non-generated output class
def plot_loss(losses):
    display.clear_output(wait=True)
    display.display(plt.gcf())
    plt.figure(figsize=(10,8))
    plt.plot(losses["d"], label='discriminitive loss_a')
    plt.plot(losses["r"], label='discriminitive loss_b')
    plt.plot(losses["g"], label='generative loss')
    plt.legend()
    plt.show()
    
def train_gan(epochs=5):
    losses = {"d":[], "g":[], "r":[]}
    for i in range(epochs):
        print ("Epoch: %d "%(i))
        make_trainable(discriminator,True)
        print("Train on real imgs")
        X, Y = real_imgs()
        train_disc(X,Y)
        print("Generate fake imgs")
        X, Y = gen_fake()
        #X =np.concatenate((X ,X_f), axis=0)
        #Y =np.concatenate((Y ,Y_f), axis=0)
        print("Train on fake imgs")
        #make_trainable(discriminator,True)
        train_disc(X,Y)
        #y2 = np.ones([1028,1])
        #y2 = discriminator.forward(generator.forward(noise_tr))   
        y2 = np.array([[0]] * 32)
        make_trainable(discriminator,False)
        make_trainable(generator,True)
        #callback = keras.callbacks.ProgbarLogger(count_mode='samples')
        #g_loss = 
        for i in range(20):
            noise_tr = np.random.uniform(0,1,size=[32,100])
            #GAN.train_on_batch(noise_tr, y2 )#,callbacks = callback)
            GAN.fit(noise_tr, y2, verbose= 0)
            
        #losses["g"].append(g_loss)
        print(GAN.weights)
        plot_gen()
    plot_loss(losses)

plot_gen()
print("Train on real imgs")
X, Y = real_imgs()
print("Generate fake imgs")
X_f, Y_f = gen_fake()
print("Done")
X =np.concatenate((X ,X_f), axis=0)
Y =np.concatenate((Y ,Y_f), axis=0)
print("Train on fake imgs")
make_trainable(discriminator,True)
train_disc(X,Y, 2)

train_gan(100)
# Out:
# Train on real imgs
# Generate fake imgs
# Done
# Train on fake imgs
# Epochs on discriminator left: 2
# Epoch 1/1
# 3327/3327 [==============================] - 72s 22ms/step - loss: 0.0228
# Epochs on discriminator left: 1
# Epoch 1/1
# 3327/3327 [==============================] - 71s 21ms/step - loss: 0.0054
# Epoch: 0
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 4.4392e-04
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 21ms/step - loss: 1.6071
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 1
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 64s 23ms/step - loss: 1.2409e-04
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 22ms/step - loss: 1.1321
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 2
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 66s 23ms/step - loss: 0.0024
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 16s 32ms/step - loss: 1.1175
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 3
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 62s 22ms/step - loss: 6.2090e-04
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 21ms/step - loss: 0.5452
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 4
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 8.3272e-04
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 0.0056
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 5
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 62s 22ms/step - loss: 2.2140e-06
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 21ms/step - loss: 1.1921e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 6
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 62s 22ms/step - loss: 1.4112e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 7.1064e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 7
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 1.2304e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 1.3018e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 8
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 1.1134e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 2.7275e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 9
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 1.0947e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 1.4067e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 10
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 1.0769e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 1.3709e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 11
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 61s 22ms/step - loss: 1.0659e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# ...
# Epoch: 81
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 94s 33ms/step - loss: 1.0014e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 21ms/step - loss: 1.1921e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 82
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 95s 34ms/step - loss: 1.0002e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 1.1921e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 83
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 96s 34ms/step - loss: 1.0008e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 10s 21ms/step - loss: 1.1921e-07
# [<tf.Variable 'dense_1/kernel:0' shape=(100, 12288) dtype=float32_ref>, <tf.Variable 'dense_1/bias:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/gamma:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/beta:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'conv2d_1/kernel:0' shape=(5, 5, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/kernel:0' shape=(2, 2, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_2/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_3/kernel:0' shape=(5, 5, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_3/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_4/kernel:0' shape=(5, 5, 128, 3) dtype=float32_ref>, <tf.Variable 'conv2d_4/bias:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/gamma:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/beta:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_mean:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_1/moving_variance:0' shape=(12288,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_2/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_3/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_4/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_mean:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'batch_normalization_5/moving_variance:0' shape=(3,) dtype=float32_ref>, <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 3, 128) dtype=float32_ref>, <tf.Variable 'conv2d_5/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_6/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_6/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_6/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_7/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_7/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_7/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/gamma:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/beta:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_mean:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'batch_normalization_8/moving_variance:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'conv2d_8/kernel:0' shape=(4, 4, 128, 128) dtype=float32_ref>, <tf.Variable 'conv2d_8/bias:0' shape=(1 ...
# Epoch: 84
# Train on real imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 2827/2827 [==============================] - 99s 35ms/step - loss: 1.0011e-07
# Generate fake imgs
# Train on fake imgs
# Epochs on discriminator left: 1
# Epoch 1/1
# 500/500 [==============================] - 11s 21ms/step - loss: 1.1921e-07

# %%
make_trainable(discriminator,True)
print("Train on real imgs")
X, Y = real_imgs()
train_disc(X,Y)
